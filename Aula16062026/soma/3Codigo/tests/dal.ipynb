# %%
def reader():
    pass

# %%
def reader():
    i = 0
    dados = [0,0]
    while i <2:
        dados[i] = float(input(f'Digite a parcela {i+1}'))
        i+=1
    return dados

# %%
dados = reader()
# Out:
# Digite a parcela 1 5
# Digite a parcela 2 8

# %%
dados
# Out:
# [5.0, 8.0]

# %%
def writer():
    pass

# %%
def writer(dados: list) -> None:
    with open('arquivo.txt', 'w', encoding='utf-8') as arquivo:
        conteudo = arquivo.write(str(dados))

# %%
writer(dados)
