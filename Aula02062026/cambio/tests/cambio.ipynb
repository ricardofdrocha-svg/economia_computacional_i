# %%
import pandas as pd

# %%
cambio = pd.read_csv('cambio.csv')

# %%
cambio.head()
# Out:
#          Data  \
# 0  02/01/2001
# 1  03/01/2001
# 2  04/01/2001
# 3  05/01/2001
# 4  06/01/2001
#
#    Taxa de câmbio - R$ / US$ - comercial - futuro: vencimento em t+1 - R$ - Bolsa de Valores- Mercadorias e Futuros (BM&FBovespa) - BMF366_FUT1DOL366  \
# 0                                           1.959736
# 1                                           1.965246
# 2                                           1.957205
# 3                                           1.972200
# 4                                                NaN
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
cambio.head(6)
# Out:
#          Data  \
# 0  02/01/2001
# 1  03/01/2001
# 2  04/01/2001
# 3  05/01/2001
# 4  06/01/2001
# 5  07/01/2001
#
#    Taxa de câmbio - R$ / US$ - comercial - futuro: vencimento em t+1 - R$ - Bolsa de Valores- Mercadorias e Futuros (BM&FBovespa) - BMF366_FUT1DOL366  \
# 0                                           1.959736
# 1                                           1.965246
# 2                                           1.957205
# 3                                           1.972200
# 4                                                NaN
# 5                                                NaN
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN

# %%
cambio.tail()
# Out:
#             Data  \
# 9277  28/05/2026
# 9278  29/05/2026
# 9279  30/05/2026
# 9280  31/05/2026
# 9281  01/06/2026
#
#       Taxa de câmbio - R$ / US$ - comercial - futuro: vencimento em t+1 - R$ - Bolsa de Valores- Mercadorias e Futuros (BM&FBovespa) - BMF366_FUT1DOL366  \
# 9277                                            5.04944
# 9278                                            5.07550
# 9279                                                NaN
# 9280                                                NaN
# 9281                                            5.04438
#
#       Unnamed: 2
# 9277         NaN
# 9278         NaN
# 9279         NaN
# 9280         NaN
# 9281         NaN

# %%
type(cambio)
# Out:
# pandas.DataFrame

# %%
api = 'https://dados.tce.rs.gov.br/dados/municipal/prev-receitas/2026.csv'
dados = pd.read_csv(api)

# %%
dados.head()
# Out:
#     ANO  CD_ORGAO         NOME  CD_RECEBIMENTO           CD_CONTA_SG  \
# 0  2026     40100  PM DE AGUDO          380683  11125001010000000000
# 1  2026     40100  PM DE AGUDO          380683  11125001010000000000
# 2  2026     40100  PM DE AGUDO          380683  11125001020000000000
# 3  2026     40100  PM DE AGUDO          380683  11125001020000000000
# 4  2026     40100  PM DE AGUDO          380683  11125001030000000000
#
#                   DS_CONTA_SG  VL_ARRECADADO
# 0  IPTU - Principal - PROPRIO     -250082.37
# 1  IPTU - Principal - PROPRIO     1387744.36
# 2      IPTU - Principal - MDE     -122767.38
# 3      IPTU - Principal - MDE      681255.97
# 4     IPTU - Principal - ASPS      454169.06
