# %%
import pandas as pd

# %%
preco = pd.read_csv('preco.csv')

# %%
quantidade = pd.read_csv('quantidade.csv')

# %%
preco.head()
# Out:
#    Data  \
# 0  1973
# 1  1974
# 2  1975
# 3  1976
# 4  1977
#
#    Preço médio - gás GLP - tonelada - R$ - Agência Nacional do Petróleo (ANP) - ANP_PRGLP  \
# 0                                             1240.0
# 1                                             1960.0
# 2                                             2640.0
# 3                                             3440.0
# 4                                             4940.0
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
quantidade.head()
# Out:
#    Data  \
# 0  1979
# 1  1980
# 2  1981
# 3  1982
# 4  1983
#
#    Consumo aparente - gás GLP - média - quantidade/dia - Barril - Agência Nacional do Petróleo (ANP) - ANP12_CGLP12  \
# 0                                               80.0
# 1                                               85.0
# 2                                               91.0
# 3                                              102.0
# 4                                              106.0
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
preco_inicial = float(input("Digite o valor: \n"))
preco = float(input("Digite o valor: \n"))
quantidade_inicial = float(input("Digite o valor: \n"))
quantidade = float(input("Digite o valor: \n"))
# Out:
# Digite o valor:
#  2
# Digite o valor:
#  1
# Digite o valor:
#  3
# Digite o valor:
#  4

# %%
import math

# %%
if quantidade_inicial != 0 and preco_inicial != 0 and quantidade/quantidade_inicial != 0 and preco/preco_inicial !=0 and preco/preco_inicial != 1:
    e = (math.log(quantidade/quantidade_inicial))/(math.log(preco/preco_inicial))
    print(f"\nO valor da elasticidade-preço da demanda é igual a {e}.\n")
else:
    print("Erro! Valores inválidos ou preço inalterado")
# Out:
# O valor da elasticidade-preço da demanda é igual a -0.4150374992788437.
