# %%
factorial(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 factorial(3)
#
# NameError: name 'factorial' is not defined

# %%
import math
math.factorial(3)
# Out:
# 6
